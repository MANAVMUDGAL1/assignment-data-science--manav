# %% [markdown]
# Question NO. 1 We have shared a dataset on which you will have to perform
# Data analysis with pandas, matplotlib and seaborn. And please
# make sure create all charts that we have teach in our previous
# class. And code should be with well commented. And Mention
# your theoretical observation in comment what you will
# observed by the charts. And try with different columns and
# different charts.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# reading score and writing score make positive relation with each other

# %%
sns.relplot(x='writing score',y='reading score',data=df,hue='race/ethnicity')
plt.title('POSITIVE RELATION')
plt.show()

# %% [markdown]
# male have given more exam in comparison to female

# %%
sns.relplot(x='writing score',y='reading score',data=df,hue='race/ethnicity',col='gender')

plt.show()

# %% [markdown]
# all group have positive relation but student of group c have given more exam

# %%
sns.relplot(x='writing score',y='reading score',data=df,hue='gender',style='race/ethnicity',row='race/ethnicity')

# %% [markdown]
# all groups have positive relation

# %%
sns.relplot(x='writing score',y='reading score',data=df,hue='gender',style='race/ethnicity',col='race/ethnicity',kind='line')

# %% [markdown]
# group A has most associate degree when test preparation course is none group D has most associate degree when test preparation course is completed

# %%
sns.relplot(x='race/ethnicity',y='parental level of education',data=df,hue='gender',style='lunch',col='test preparation course',kind='line')

# %% [markdown]
# standard lunch have more reading score

# %%
sns.catplot(x='lunch',y='reading score',data=df,kind="bar",color='pink')

# %% [markdown]
# group E has more reading score

# %%
sns.catplot(x='race/ethnicity',y='reading score',data=df,kind="bar",color='pink')

# %%
sns.catplot(x='race/ethnicity',y='writing score',data=df,kind="violin",color='red')

# %%
sns.catplot(x='race/ethnicity',y='math score',data=df,kind="strip",color='violet')

# %%
sns.barplot(x='parental level of education',y='reading score',data=df,hue='lunch')
# Out:
# <Axes: xlabel='parental level of education', ylabel='reading score'>

# %%
label=list(df['parental level of education'].value_counts().keys())
label
# Out:
# ['some college',
#  "associate's degree",
#  'high school',
#  'some high school',
#  "bachelor's degree",
#  "master's degree"]

# %%
values=list(df['parental level of education'].value_counts().values)
values
# Out:
# [226, 222, 196, 179, 118, 59]

# %%
ls=[0,0,0,0.5,0,0]
#sns.set(rc={'figure.figsize':(10,10)})
sns.set(rc={'figure.figsize':(8,8)})
plt.pie(values,labels=label,wedgeprops={'ec':'k'},explode=ls,autopct="%1.2f%%",shadow=True)
plt.title('Daywise')
#plt.savefig("piechart")
plt.show()

# %%
sns.catplot(x='parental level of education',y='writing score',data=df,kind='bar',hue='gender',row='race/ethnicity')

# %%
sns.boxplot(df['math score'])
# Out:
# <Axes: ylabel='math score'>
